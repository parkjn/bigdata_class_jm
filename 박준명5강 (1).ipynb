# %%
import pandas as pd
data={'age':[23,43,12,45],'name':['민준','현우','서연','동현'],'height':[175.3,180.3,165.8,172.7]}
x=pd.DataFrame(data,columns=['name','age','height'])
x
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7

# %%
x.loc[4]=['광현',32,176]

# %%
x
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0

# %%
y=pd.DataFrame({'age':[33],'name':['철수'],'height':[180]},columns=['age','name','height'])
y
# Out:
#    age name  height
# 0   33   철수     180

# %%
result=x.append(y)

# %%
result
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 0   철수   33   180.0

# %%
result=x.append(y,ignore_index=True)
result
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 5   철수   33   180.0

# %%
result=pd.concat([x,y],ignore_index=True)

# %%
result
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 5   철수   33   180.0

# %%
import numpy as np
df=pd.DataFrame(np.random.randn(5,5))
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           0         1         2         3         4
# 0  0.846726  2.118856 -0.452243  0.372677  0.228764
# 1  0.592476       NaN -0.062224 -0.023436 -0.052121
# 2 -0.830133  0.488741       NaN -1.659350 -1.390998
# 3  1.257502  0.730826  1.046833  0.243760 -0.219283
# 4 -2.219911  0.880248  0.069457  1.414290  0.107819

# %%
df=pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.864875  0.942407  0.001922  0.313178 -0.566158
# 1  0.734974       NaN -0.308402 -0.221583  2.065341
# 2  0.538504 -1.610034       NaN -0.616063 -1.393378
# 3 -0.163839 -0.446308 -0.177479 -0.257109 -1.419867
# 4  1.301590  0.923580 -1.558545 -0.836054  0.183633

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df['C'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: C, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#           A   B         C         D         E
# 1  0.734974 NaN -0.308402 -0.221583  2.065341

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df.dropna()
# Out:
#           A         B         C         D         E
# 0  0.864875  0.942407  0.001922  0.313178 -0.566158
# 3 -0.163839 -0.446308 -0.177479 -0.257109 -1.419867
# 4  1.301590  0.923580 -1.558545 -0.836054  0.183633

# %%
df.dropna(inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  0.864875  0.942407  0.001922  0.313178 -0.566158
# 3 -0.163839 -0.446308 -0.177479 -0.257109 -1.419867
# 4  1.301590  0.923580 -1.558545 -0.836054  0.183633

# %%
df.dropna(subset=['B'],axis=0,inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  0.864875  0.942407  0.001922  0.313178 -0.566158
# 3 -0.163839 -0.446308 -0.177479 -0.257109 -1.419867
# 4  1.301590  0.923580 -1.558545 -0.836054  0.183633

# %%
df.dropna(axis=1,inplace=True)
df
# Out:
#           A         B         C         D         E
# 0  0.864875  0.942407  0.001922  0.313178 -0.566158
# 3 -0.163839 -0.446308 -0.177479 -0.257109 -1.419867
# 4  1.301590  0.923580 -1.558545 -0.836054  0.183633

# %%
robots=[[23,23680],[35,np.nan],[46,47350],[27,np.nan]]
data=pd.DataFrame(robots,columns=['max_speed','price'])
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
data.replace(np.nan,0,inplace=True)
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean=data['price'].mean()
data.replace(np.nan,mean,inplace=True)
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean=data['price'].mean()
data.replace(np.nan,mean)
data
# Out:
#    max_speed    price
# 0         23  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
import seaborn as sns

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
vals=iris['sepal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for sepal length")
plt.show()

# %%
vals=iris['petal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for petal length")
plt.show()

# %%
vals=iris['petal_length'].values
sns.distplot(vals,kde=True,rug=True)
plt.title("kdeplot for petal length")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(vals,kde=True,rug=True)
plt.title("displot for petal length")
plt.show()

# %%
sns.histplot(vals,kde=True)
plt.title("hisplot for petal length")
plt.show()

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="adult_male",data=titanic)
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='scatter')
plt.show()

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,hue='species',kind='kde')
plt.show()

# %%
sns.pairplot(iris,hue='species',markers=['o','s','d'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
titanic_size=titanic.pivot_table(index="class",columns="sex",aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size,annot=True)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size,annot=True,fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size,cmap=sns.color_palette("PuBu"),annot=True,fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.barplot(x="day",y="total_bill",data=tips)
plt.title("Tips in each day")
plt.show()

# %%
sns.barplot(x="total_bill",y="day",data=tips)
plt.title("Tips on each day")
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=tips, jitter=True)
plt.title('Tips on each day')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=tips, jitter=False)
plt.title('Tips on each day')
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.title('Tips on each day')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips, jitter=False)
plt.title('Tips on each day')
plt.show()

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.barplot(x='day',y='total_bill',hue='time',data=tips)
plt.title('Tips on each day with hue=time')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',hue='sex',data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',hue='sex',data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',hue='sex',data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',hue='sex',data=tips,split=True)
plt.title('Tips on each day with option hue=sex and split=True')
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',hue='sex',data=tips,dodge=True)
plt.title('Tips on each day with option hue=sex and dodge=True')
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',hue='sex',data=tips,dodge=True)
plt.title('Tips on each day with option hue=sex and dodge=True')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='age',y='sex',hue='survived',row="class",data=titanic,kind="violin",split=True,height=2,aspect=4)
plt.title('Catplot of titanic with hue=survived')
plt.show()

# %%
plt.title("violinplot and swarmplot")
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='0.9')
plt.show
# Out:
# <function matplotlib.pyplot.show>
